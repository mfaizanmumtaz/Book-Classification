# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema.output_parser import StrOutputParser
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain.schema.runnable import RunnablePassthrough
import os
load_dotenv()

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = "Books Classifications"

model = ChatOpenAI(model="gpt-3.5-turbo",temperature=0)

# %%
SWEBOK_categories = """Software Requirements
Software Design
Software Construction
Software Testing
Software Maintenance
Software Configuration Management
Software Engineering Management
Software Engineering Process
Software Engineering Models and Methods
Software Quality
Software Engineering Professional Practice
Software Engineering Economics
Computing Foundations
Mathematical Foundations
Engineering Foundations"""

prompt = ChatPromptTemplate.from_messages(
    [
("user","""Your objective is to categorize chapters titles and sections into SWEBOK categories, identified by #### delimiters. Chapters titles and sections are demarcated by triple backticks.

Ensure to adhere to the following instructions:
- Thoroughly analyze each chapter titles and section in conjunction with SWEBOK categories before assigning a label, as accuracy is crucial for my career.
- Avoid generating any additional text, as it may have adverse effects.
- Provide your output in CSV format:
Example format:
There Will Be Code,Software Construction
Bad Code,Software Quality

> SWEBOK Categories: ####\n{SWEBOK_categories} ####

-----------

> Titles and Sections: ```\n{Titles_and_Sections} ```
""")])

prompt = prompt.partial(SWEBOK_categories=SWEBOK_categories)

chain = prompt | ChatGoogleGenerativeAI(model="gemini-pro",temperature=0) | StrOutputParser()

# %%
import pandas as pd

def data():

    Titles_and_Sections = []

    if any(file.endswith('.xlsx') for file in os.listdir('data')):

        for xlsx in os.listdir("data"):
            df = pd.read_excel(os.path.join("data",xlsx))

            if "chapter_section_titles" in df.columns:
                Titles_and_Sections.extend(df['chapter_section_titles'].tolist())
                
            else:
                print(f"No column found with name 'Titles_and_Sections' in {xlsx} file.")
    else:
        print("No Excel file found in Data Directory!")

    return Titles_and_Sections
    
def chunking(items):

    chunk_size = 30

    return [{"Titles_and_Sections":"\n".join(items[i:i + chunk_size])} for i in range(0, len(items), chunk_size)]

title_and_sections = RunnablePassthrough() | chunking | chain.map()

output = "\n".join(title_and_sections.invoke(data()))
# Out:
# No column found with name 'Titles_and_Sections' in swebok_area.xlsx file.

# %%
print(output)
# Out:
# There Will Be Code,Software Construction
# Bad Code,Software Quality
# The Total Cost of Owning a Mess,Software Maintenance
# The Grand Redesign in the Sky,Software Maintenance
# Attitude,Software Engineering Professional Practice
# The Primal Conundrum,Software Engineering Professional Practice
# The Art of Clean Code?,Software Engineering Professional Practice
# What Is Clean Code?,Software Engineering Professional Practice
# Schools of Thought,Software Engineering Professional Practice
# We Are Authors,Software Engineering Professional Practice
# The Boy Scout Rule,Software Engineering Professional Practice
# Prequel and Principles,Software Engineering Professional Practice
# Conclusion,Software Engineering Professional Practice
# Introduction,Software Design
# Use Intention-Revealing Names,Software Design
# Avoid Disinformation,Software Design
# Make Meaningful Distinctions,Software Design
# Use Pronounceable Names,Software Design
# Use Searchable Names,Software Design
# Avoid Encodings,Software Design
# Hungarian Notation,Software Design
# Member Prefixes,Software Design
# Interfaces and Implementations,Software Design
# Avoid Mental Mapping,Software Design
# Class Names,Software Design
# Method Names,Software Design
# Don’t Be Cute,Software Design
# Pick One Word per Concept,Software Design
# Don’t Pun,Software Quality
# Use Solution Domain Names,Software Quality
# Use Problem Domain Names,Software Quality
# Add Meaningful Context,Software Quality
# Don’t Add Gratuitous Context,Software Quality
# Final Words,Software Quality
# Chapter 3: Functions,Software Design
# Small!,Software Design
# Blocks and Indenting,Software Design
# Do One Thing,Software Design
# Sections within Functions,Software Design
# One Level of Abstraction per Function,Software Design
# Reading Code from Top to Bottom: The Stepdown Rule,Software Design
# Switch Statements,Software Design
# Use Descriptive Names,Software Design
# Function Arguments,Software Design
# Common Monadic Forms,Software Design
# Flag Arguments,Software Design
# Dyadic Functions,Software Design
# Triads,Software Design
# Argument Objects,Software Design
# Argument Lists,Software Design
# Verbs and Keywords,Software Design
# Have No Side Effects,Software Design
# Output Arguments,Software Design
# Command Query Separation,Software Design
# Prefer Exceptions to Returning Error Codes,Software Design
# Extract Try/Catch Blocks,Software Design
# Error Handling Is One Thing,Software Design
# The Error.java Dependency Magnet,Software Design
# Don’t Repeat Yourself,Software Design
# Structured Programming,Software Design
# How Do You Write Functions Like This?,Software Design
# Conclusion,Software Design
# SetupTeardownIncluder,Software Construction
# Chapter 4: Comments,Software Design
# Comments Do Not Make Up for Bad Code,Software Quality
# Explain Yourself in Code,Software Design
# Good Comments,Software Quality
# Legal Comments,Software Design
# Informative Comments,Software Quality
# Explanation of Intent,Software Design
# Clarification,Software Design
# Warning of Consequences,Software Design
# TODO Comments,Software Design
# Amplification,Software Design
# Javadocs in Public APIs,Software Design
# Bad Comments,Software Quality
# Mumbling,Software Quality
# Redundant Comments,Software Quality
# Misleading Comments,Software Quality
# Mandated Comments,Software Quality
# Journal Comments,Software Quality
# Noise Comments,Software Quality
# Scary Noise,Software Quality
# Don’t Use a Comment When You Can Use a Function or a Variable,Software Design
# Position Markers,Software Design
# Closing Brace Comments,Software Design
# Attributions and Bylines,Software Design
# Commented-Out Code,Software Construction
# HTML Comments,Software Construction
# Nonlocal Information,Software Design
# Too Much Information,Software Design
# Inobvious Connection,Software Design
# Function Headers,Software Construction
# Javadocs in Nonpublic Code,Software Construction
# Example,Software Construction
# Chapter 5: Formatting,Software Construction
# The Purpose of Formatting,Software Construction
# Vertical Formatting,Software Construction
# The Newspaper Metaphor,Software Construction
# Vertical Openness Between Concepts,Software Construction
# Vertical Density,Software Construction
# Vertical Distance,Software Construction
# Vertical Ordering,Software Construction
# Horizontal Formatting,Software Construction
# Horizontal Openness and Density,Software Construction
# Horizontal Alignment,Software Construction
# Indentation,Software Construction
# Dummy Scopes,Software Construction
# Team Rules,Software Engineering Management
# Uncle Bob’s Formatting Rules,Software Engineering Management
# Chapter 6: Objects and Data Structures,Software Design
# Data Abstraction,Software Design
# Data/Object Anti-Symmetry,Software Design
# The Law of Demeter,Software Design
# Train Wrecks,Software Design
# Hybrids,Software Design
# Hiding Structure,Software Design
# Data Transfer Objects,Software Design
# Active Record,Software Construction
# Conclusion,Software Engineering Process
# Chapter 7: Error Handling,Software Construction
# Use Exceptions Rather Than Return Codes,Software Construction
# Write Your Try-Catch-Finally Statement First,Software Construction
# Use Unchecked Exceptions,Software Construction
# Provide Context with Exceptions,Software Construction
# Define Exception Classes in Terms of a Caller’s Needs,Software Construction
# Define the Normal Flow,Software Construction
# Don’t Return Null,Software Construction
# Don’t Pass Null,Software Construction
# Conclusion,Software Engineering Process
# Chapter 8: Boundaries,Software Construction
# Using Third-Party Code,Software Construction
# Exploring and Learning Boundaries,Software Construction
# Learning log4j,Software Construction
# Learning Tests Are Better Than Free,Software Construction
# Using Code That Does Not Yet Exist,Software Construction
# Clean Boundaries,Software Construction
# Chapter 9: Unit Tests,Software Testing
# The Three Laws of TDD,Software Testing
# Keeping Tests Clean,Software Testing
# Tests Enable the -ilities,Software Testing
# Clean Tests,Software Testing
# Domain-Specific Testing Language,Software Testing
# A Dual Standard,Software Testing
# One Assert per Test,Software Testing
# Single Concept per Test,Software Testing
# F.I.R.S.T.,Software Testing
# Conclusion,Software Engineering Process
# Chapter 10: Classes,Software Design
# Class Organization,Software Design
# Encapsulation,Software Design
# Classes Should Be Small!,Software Design
# The Single Responsibility Principle,Software Design
# Cohesion,Software Design
# Maintaining Cohesion Results in Many Small Classes,Software Design
# Organizing for Change,Software Design
# Isolating from Change,Software Design
# Chapter 11: Systems,Software Design
# How Would You Build a City?,Software Design
# Separate Constructing a System from Using It,Software Design
# Separation of Main,Software Design
# Factories,Software Design
# Dependency Injection,Software Design
# Scaling Up,Software Design
# Cross-Cutting Concerns,Software Design
# Java Proxies,Software Design
# Pure Java AOP Frameworks,Software Design
# AspectJ Aspects,Software Design
# Test Drive the System Architecture,Software Design
# Optimize Decision Making,Software Design
# Use Standards Wisely, When They Add Demonstrable Value,Software Design
# Systems Need Domain-Specific Languages,Software Design
# Conclusion,Software Design
# Chapter 12: Emergence,Software Design
# Getting Clean via Emergent Design,Software Design
# Simple Design Rule 1: Runs All the Tests,Software Design
# Simple Design Rules 2–4: Refactoring,Software Design
# No Duplication,Software Design
# Expressive,Software Design
# Minimal Classes and Methods,Software Design
# Conclusion,Software Design
# Chapter 13: Concurrency,Software Design
# Why Concurrency?,Software Design
# Myths and Misconceptions,Software Design
# Challenges,Software Design
# Concurrency Defense Principles,Software Design
# Single Responsibility Principle,Software Design
# Corollary: Limit the Scope of Data,Software Design
# Corollary: Use Copies of Data,Software Design
# Corollary: Threads Should Be as Independent as Possible,Software Design
# Know Your Library,Software Design
# Thread-Safe Collections,Software Design
# Know Your Execution Models,Software Design
# Producer-Consumer,Software Design
# Readers-Writers,Software Design
# Dining Philosophers,Software Design
# Beware Dependencies Between Synchronized Methods,Software Design
# Keep Synchronized Sections Small,Software Design
# Writing Correct Shut-Down Code Is Hard,Software Design
# Testing Threaded Code,Software Testing
# Treat Spurious Failures as Candidate Threading Issues,Software Testing
# Get Your Nonthreaded Code Working First,Software Testing
# Make Your Threaded Code Pluggable,Software Testing
# Make Your Threaded Code Tunable,Software Testing
# Run with More Threads Than Processors,Software Testing
# Run on Different Platforms,Software Testing
# Instrument Your Code to Try and Force Failures,Software Testing
# Hand-Coded,Software Construction
# Automated,Software Construction
# Conclusion,Software Engineering Process
# Chapter 14: Successive Refinement,Software Engineering Process
# Args Implementation,Software Construction
# How Did I Do This?,Software Engineering Process
# Args: The Rough Draft,Software Construction
# So I Stopped,Software Engineering Process
# On Incrementalism,Software Engineering Process
# String Arguments,Software Construction
# Conclusion,Software Engineering Process
# Chapter 15: JUnit Internals,Software Testing
# The JUnit Framework,Software Testing
# Conclusion,Software Engineering Process
# Chapter 16: Refactoring SerialDate,Software Construction
# First, Make It Work,Software Construction
# Then Make It Right,Software Construction
# Conclusion,Software Engineering Process
# Chapter 17: Smells and Heuristics,Software Quality
# Comments,Software Quality
# C1: Inappropriate Information,Software Quality
# C2: Obsolete Comment,Software Quality
# C3: Redundant Comment,Software Quality
# C4: Poorly Written Comment,Software Quality
# C5: Commented-Out Code,Software Quality
# Environment,Software Quality
# E1: Build Requires More Than One Step,Software Quality
# E2: Tests Require More Than One Step,Software Quality
# Functions,Software Quality
# F1: Too Many Arguments,Software Quality
# F2: Output Arguments,Software Quality
# F3: Flag Arguments,Software Construction
# F4: Dead Function,Software Construction
# G1: Multiple Languages in One Source File,Software Construction
# G2: Obvious Behavior Is Unimplemented,Software Construction
# G3: Incorrect Behavior at the Boundaries,Software Construction
# G4: Overridden Safeties,Software Construction
# G5: Duplication,Software Construction
# G6: Code at Wrong Level of Abstraction,Software Construction
# G7: Base Classes Depending on Their Derivatives,Software Construction
# G8: Too Much Information,Software Construction
# G9: Dead Code,Software Construction
# G10: Vertical Separation,Software Construction
# G11: Inconsistency,Software Construction
# G12: Clutter,Software Construction
# G13: Artificial Coupling,Software Construction
# G14: Feature Envy,Software Construction
# G15: Selector Arguments,Software Construction
# G16: Obscured Intent,Software Construction
# G17: Misplaced Responsibility,Software Construction
# G18: Inappropriate Static,Software Construction
# G19: Use Explanatory Variables,Software Construction
# G20: Function Names Should Say What They Do,Software Construction
# G21: Understand the Algorithm,Software Construction
# G22: Make Logical Dependencies Physical,Software Construction
# G23: Prefer Polymorphism to If/Else or Switch/Case,Software Construction
# G24: Follow Standard Conventions,Software Construction
# G25: Replace Magic Numbers with Named Constants,Software Construction
# G26: Be Precise,Software Construction
# G27: Structure over Convention,Software Construction
# G28: Encapsulate Conditionals,Software Design
# G29: Avoid Negative Conditionals,Software Design
# G30: Functions Should Do One Thing,Software Design
# G31: Hidden Temporal Couplings,Software Design
# G32: Don’t Be Arbitrary,Software Design
# G33: Encapsulate Boundary Conditions,Software Design
# G34: Functions Should Descend Only One Level of Abstraction,Software Design
# G35: Keep Configurable Data at High Levels,Software Design
# G36: Avoid Transitive Navigation,Software Design
# J1: Avoid Long Import Lists by Using Wildcards,Software Construction
# J2: Don’t Inherit Constants,Software Construction
# J3: Constants versus Enums,Software Construction
# N1: Choose Descriptive Names,Software Quality
# N2: Choose Names at the Appropriate Level of Abstraction,Software Quality
# N3: Use Standard Nomenclature Where Possible,Software Quality
# N4: Unambiguous Names,Software Quality
# N5: Use Long Names for Long Scopes,Software Quality
# N6: Avoid Encodings,Software Quality
# N7: Names Should Describe Side-Effects.,Software Quality
# T1: Insufficient Tests,Software Testing
# T2: Use a Coverage Tool!,Software Testing
# T3: Don’t Skip Trivial Tests,Software Testing
# T4: An Ignored Test Is a Question about an Ambiguity,Software Testing
# T5: Test Boundary Conditions,Software Testing
# T6: Exhaustively Test Near Bugs,Software Testing
# T7: Patterns of Failure Are Revealing,Software Testing
# T8: Test Coverage Patterns Can Be Revealing,Software Testing
# T9: Tests Should Be Fast,Software Testing
# Conclusion,Software Engineering Process
# Part I Laying the Foundation,Software Engineering Process
# 1 Welcome to Software Construction,Software Construction
# 1.1. What Is Software Construction?,Software Construction
# 1.2. Why Is Software Construction Important?,Software Construction
# 1.3. How to Read This Book,Software Engineering Process
# 2 Metaphors for a Richer Understanding of Software Development,Software Engineering Process
# 2.1. The Importance of Metaphors,Software Engineering Process
# 2.2. How to Use Software Metaphors,Software Engineering Process
# 2.3. Common Software Metaphors,Software Engineering Process
# 3 Measure Twice, Cut Once: Upstream Prerequisites,Software Engineering Process
# 3.1. Importance of Prerequisites,Software Engineering Process
# 3.2. Determine the Kind of Software You're Working On,Software Engineering Process
# 3.3. Problem-Definition Prerequisite,Software Engineering Process
# 3.4. Requirements Prerequisite,Software Engineering Process
# 3.5. Architecture Prerequisite,Software Engineering Process
# 3.6. Amount of Time to Spend on Upstream Prerequisites,Software Engineering Process
# 4 Key Construction Decisions,Software Construction
# 4.1. Choice of Programming Language,Software Construction
# 4.2. Programming Conventions,Software Construction
# 4.3. Your Location on the Technology Wave,Software Construction
# 4.4. Selection of Major Construction Practices,Software Construction
# Part II Creating High-Quality Code,Software Construction
# 5 Design in Construction,Software Design
# 5.1. Design Challenges,Software Design
# 5.2. Key Design Concepts,Software Design
# 5.3. Design Building Blocks: Heuristics,Software Design
# 5.4. Design Practices,Software Design
# 5.5. Comments on Popular Methodologies,Software Design
# 6 Working Classes,Software Design
# 6.1. Class Foundations: Abstract Data Types (ADTs),Software Design
# 6.2. Good Class Interfaces,Software Design
# 6.3. Design and Implementation Issues,Software Design
# 6.4. Reasons to Create a Class,Software Design
# 6.5. Language-Specific Issues,Software Design
# 6.6. Beyond Classes: Packages,Software Design
# 7 High-Quality Routines,Software Design
# 7.1. Valid Reasons to Create a Routine,Software Design
# 7.2. Design at the Routine Level,Software Design
# 7.3. Good Routine Names,Software Design
# 7.4. How Long Can a Routine Be?,Software Design
# 7.5. How to Use Routine Parameters,Software Design
# 7.6. Special Considerations in the Use of Functions,Software Design
# 7.7. Macro Routines and Inline Routines,Software Design
# 8 Defensive Programming,Software Quality
# 8.1. Protecting Your Program from Invalid Inputs,Software Quality
# 8.2. Assertions,Software Quality
# 8.3. Error-Handling Techniques,Software Quality
# 8.4. Exceptions,Software Quality
# 8.5. Barricade Your Program to Contain the Damage Caused by Errors,Software Quality
# 8.6. Debugging Aids,Software Quality
# 8.7. Determining How Much Defensive Programming to Leave in Production Code,Software Quality
# 8.8. Being Defensive About Defensive Programming,Software Quality
# 9 The Pseudocode Programming Process,Software Design
# 9.1. Summary of Steps in Building Classes and Routines,Software Design
# 9.2. Pseudocode for Pros,Software Design
# 9.3. Constructing Routines by Using the PPP,Software Design
# 9.4. Alternatives to the PPP,Software Design
# 10 General Issues in Using Variables,Software Design
# 10.1. Data Literacy,Software Design
# 10.2. Making Variable Declarations Easy,Software Design
# 10.3. Guidelines for Initializing Variables,Software Design
# 10.4. Scope,Software Design
# 10.5. Persistence,Software Design
# 10.6. Binding Time,Software Design
# 10.7. Relationship Between Data Types and Control Structures,Software Design
# 10.8. Using Each Variable for Exactly One Purpose,Software Design
# 11 The Power of Variable Names,Software Design
# 11.1. Considerations in Choosing Good Names,Software Design
# 11.2. Naming Specific Types of Data,Software Design
# 11.3. The Power of Naming Conventions,Software Design
# 11.4. Informal Naming Conventions,Software Design
# 11.5. Standardized Prefixes,Software Design
# 11.6. Creating Short Names That Are Readable,Software Design
# 11.7. Kinds of Names to Avoid,Software Design
# 12 Fundamental Data Types,Software Design
# 12.1. Numbers in General,Software Design
# 12.2. Integers,Software Design
# 12.3. Floating-Point Numbers,Software Design
# 12.4. Characters and Strings,Software Design
# 12.5. Boolean Variables,Software Design
# 12.6. Enumerated Types,Software Design
# 12.7. Named Constants,Software Design
# 12.8. Arrays,Software Design
# 12.9. Creating Your Own Types (Type Aliasing),Software Design
# 13 Unusual Data Types,Software Design
# 13.1. Structures,Software Design
# 13.2. Pointers,Software Design
# 13.3. Global Data,Software Construction
# Part IV Statements,Software Construction
# 14 Organizing Straight-Line Code,Software Construction
# 14.1. Statements That Must Be in a Specific Order,Software Construction
# 14.2. Statements Whose Order Doesn't Matter,Software Construction
# 15 Using Conditionals,Software Construction
# 15.1. if Statements,Software Construction
# 15.2. case Statements,Software Construction
# 16 Controlling Loops,Software Construction
# 16.1. Selecting the Kind of Loop,Software Construction
# 16.2. Controlling the Loop,Software Construction
# 16.3. Creating Loops Easily—From the Inside Out,Software Construction
# 16.4. Correspondence Between Loops and Arrays,Software Construction
# 17 Unusual Control Structures,Software Construction
# 17.1. Multiple Returns from a Routine,Software Construction
# 17.2. Recursion,Software Construction
# 17.3. goto,Software Construction
# 17.4. Perspective on Unusual Control Structures,Software Construction
# 18 Table-Driven Methods,Software Construction
# 18.1. General Considerations in Using Table-Driven Methods,Software Construction
# 18.2. Direct Access Tables,Software Construction
# 18.3. Indexed Access Tables,Software Construction
# 18.4. Stair-Step Access Tables,Software Construction
# 18.5. Other Examples of Table Lookups,Software Construction
# 19 General Control Issues,Software Construction
# 19.1. Boolean Expressions,Software Construction
# 19.2. Compound Statements (Blocks),Software Construction
# 19.3. Null Statements,Software Construction
# 19.4. Taming Dangerously Deep Nesting,Software Construction
# 19.5. A Programming Foundation: Structured Programming,Software Construction
# 19.6. Control Structures and Complexity,Software Design
# Part V Code Improvements,Software Construction
# 20 The Software-Quality Landscape,Software Quality
# 20.1. Characteristics of Software Quality,Software Quality
# 20.2. Techniques for Improving Software Quality,Software Quality
# 20.3. Relative Effectiveness of Quality Techniques,Software Quality
# 20.4. When to Do Quality Assurance,Software Quality
# 20.5. The General Principle of Software Quality,Software Quality
# 21 Collaborative Construction,Software Construction
# 21.1. Overview of Collaborative Development Practices,Software Construction
# 21.2. Pair Programming,Software Construction
# 21.3. Formal Inspections,Software Construction
# 21.4. Other Kinds of Collaborative Development Practices,Software Construction
# 22 Developer Testing,Software Testing
# 22.1. Role of Developer Testing in Software Quality,Software Testing
# 22.2. Recommended Approach to Developer Testing,Software Testing
# 22.3. Bag of Testing Tricks,Software Testing
# 22.4. Typical Errors,Software Testing
# 22.5. Test-Support Tools,Software Testing
# 22.6. Improving Your Testing,Software Testing
# 22.7. Keeping Test Records,Software Testing
# 23 Debugging,Software Testing
# 23.1. Overview of Debugging Issues,Software Testing
# 23.2. Finding a Defect,Software Testing
# 23.3. Fixing a Defect,Software Testing
# 23.4. Psychological Considerations in Debugging,Software Testing
# 23.5. Debugging Tools—Obvious and Not-So-Obvious,Software Testing
# 24 Refactoring,Software Maintenance
# 24.1. Kinds of Software Evolution,Software Maintenance
# 24.2. Introduction to Refactoring,Software Maintenance
# 24.3. Specific Refactorings,Software Construction
# 24.4. Refactoring Safely,Software Construction
# 24.5. Refactoring Strategies,Software Construction
# 25 Code-Tuning Strategies,Software Construction
# 25.1. Performance Overview,Software Construction
# 25.2. Introduction to Code Tuning,Software Construction
# 25.3. Kinds of Fat and Molasses,Software Construction
# 25.4. Measurement,Software Construction
# 25.5. Iteration,Software Construction
# 25.6. Summary of the Approach to Code Tuning,Software Construction
# 26 Code-Tuning Techniques,Software Construction
# 26.1. Logic,Software Construction
# 26.2. Loops,Software Construction
# 26.3. Data Transformations,Software Construction
# 26.4. Expressions,Software Construction
# 26.5. Routines,Software Construction
# 26.6. Recoding in a Low-Level Language,Software Construction
# 26.7. The More Things Change, the More They Stay the Same,Software Construction
# 27 How Program Size Affects Construction,Software Construction
# 27.1. Communication and Size,Software Construction
# 27.2. Range of Project Sizes,Software Construction
# 27.3. Effect of Project Size on Errors,Software Construction
# 27.4. Effect of Project Size on Productivity,Software Construction
# 27.5. Effect of Project Size on Development Activities,Software Construction
# 28 Managing Construction,Software Construction
# 28.1. Encouraging Good Coding,Software Construction
# 28.2. Configuration Management,Software Configuration Management
# 28.3. Estimating a Construction Schedule,Software Construction
# 28.4. Measurement,Software Construction
# 28.5. Treating Programmers as People,Software Engineering Professional Practice
# 28.6. Managing Your Manager,Software Engineering Professional Practice
# 29 Integration,Software Construction
# 29.1. Importance of the Integration Approach,Software Construction
# 29.2. Integration Frequency—Phased or Incremental?,Software Construction
# 29.3. Incremental Integration Strategies,Software Construction
# 29.4. Daily Build and Smoke Test,Software Construction
# 30 Programming Tools,Software Construction
# 30.1. Design Tools,Software Construction
# 30.2. Source-Code Tools,Software Construction
# 30.3. Executable-Code Tools,Software Construction
# 30.4. Tool-Oriented Environments,Software Construction
# 30.5. Building Your Own Programming Tools,Software Construction
# 30.6. Tool Fantasyland,Software Construction
# 31 Layout and Style,Software Quality
# 31.1. Layout Fundamentals,Software Quality
# 31.2. Layout Techniques,Software Quality
# 31.3. Layout Styles,Software Quality
# 31.4. Laying Out Control Structures,Software Quality
# 31.5. Laying Out Individual Statements,Software Quality
# 31.6. Laying Out Comments,Software Quality
# 31.7. Laying Out Routines,Software Quality
# 31.8. Laying Out Classes,Software Quality
# 32 Self-Documenting Code,Software Quality
# 32.1. External Documentation,Software Quality
# 32.2. Programming Style as Documentation,Software Quality
# 32.3. To Comment or Not to Comment,Software Quality
# 32.4. Keys to Effective Comments,Software Quality
# 32.5. Commenting Techniques,Software Quality
# 32.6. IEEE Standards,Software Engineering Professional Practice
# 33 Personal Character,Software Engineering Professional Practice
# 33.1. Isn't Personal Character Off the Topic?,Software Engineering Professional Practice
# 33.2. Intelligence and Humility,Software Engineering Professional Practice
# 33.3. Curiosity,Software Engineering Professional Practice
# 33.4. Intellectual Honesty,Software Engineering Professional Practice
# 33.5. Communication and Cooperation,Software Engineering Professional Practice
# 33.6. Creativity and Discipline,Software Engineering Professional Practice
# 33.7. Laziness,Software Engineering Professional Practice
# 33.8. Characteristics That Don't Matter As Much As You Might Think,Software Engineering Professional Practice
# 33.9. Habits,Software Engineering Professional Practice
# 34 Themes in Software Craftsmanship,Software Construction
# 34.1. Conquer Complexity,Software Construction
# 34.2. Pick Your Process,Software Construction
# 34.3. Write Programs for People First, Computers Second,Software Construction
# 34.4. Program into Your Language, Not in It,Software Construction
# 34.5. Focus Your Attention with the Help of Conventions,Software Construction
# 34.6. Program in Terms of the Problem Domain,Software Construction
# 34.7. Watch for Falling Rocks,Software Construction
# 34.8. Iterate, Repeatedly, Again and Again,Software Construction
# 34.9. Thou Shalt Rend Software and Religion Asunder,Software Construction
# 35 Where to Find More Information,Software Engineering Professional Practice
# 35.1. Information About Software Construction,Software Construction
# 35.2. Topics Beyond Construction,Software Engineering Professional Practice
# 35.3. Periodicals,Software Engineering Professional Practice
# 35.4. A Software Developer's Reading Plan,Software Engineering Professional Practice
# 35.5. Joining a Professional Organization,Software Engineering Professional Practice
# 1 A Pragmatic Philosophy,Software Engineering Professional Practice
# 1. The Cat Ate My Source Code,Software Engineering Professional Practice
# 2 Software Entropy,Software Construction
# 3. Stone Soup and Boiled Frogs,Software Engineering Process
# 4. Good-Enough Software,Software Quality
# 5. Your Knowledge Portfolio,Software Engineering Professional Practice
# 6. Communicate!,Software Engineering Management
# 2 A Pragmatic Approach,Software Engineering Process
# 7. The Evils of Duplication,Software Design
# 8. Orthogonality,Software Design
# 9. Reversibility,Software Design
# 10. Tracer Bullets,Software Engineering Process
# 11. Prototypes and Post-it Notes,Software Engineering Process
# 12. Domain Languages,Software Design
# 13. Estimating,Software Engineering Management
# 3 The Basic Tools,Software Construction
# 14. The Power of Plain Text,Software Construction
# 15. Shell Games,Software Construction
# 16. Power Editing,Software Construction
# 17. Source Code Control,Software Configuration Management
# 18. Debugging,Software Testing
# 19. Text Manipulation,Software Construction
# 20. Code Generators,Software Construction
# 4 Pragmatic Paranoia,Software Quality
# 21. Design by Contract,Software Design
# 22. Dead Programs Tell No Lies,Software Testing
# 23. Assertive Programming,Software Quality
# 24. When to Use Exceptions,Software Design
# 25. How to Balance Resources,Software Engineering Management
# 5 Bend, or Break,Software Design
# 26. Decoupling and the Law of Demeter,Software Design
# 27. Metaprogramming,Software Construction
# 28. Temporal Coupling,Software Design
# 29. It's Just a View,Software Design
# 30. Blackboards,Software Design
# 6 While You Are Coding,Software Construction
# 31. Programming by Coincidence,Software Construction
# 32. Algorithm Speed,Software Design
# 33. Refactoring,Software Construction
# 34. Code That's Easy to Test,Software Testing
# 35. Evil Wizards,Software Quality
# 7 Before the Project,Software Engineering Process
# 36. The Requirements Pit,Software Requirements
# 37. Solving Impossible Puzzles,Software Requirements
# 38. Not Until You're Ready,Software Engineering Process
# 39. The Specification Trap,Software Requirements
# 40. Circles and Arrows,Software Engineering Process
# 8 Pragmatic Projects,Software Engineering Management
# 41. Pragmatic Teams,Software Engineering Management
# 42. Ubiquitous Automation,Software Engineering Process
# 43. Ruthless Testing,Software Testing
# 44. It's All Writing,Software Engineering Professional Practice
# 45. Great Expectations,Software Engineering Management
# 46. Pride and Prejudice,Software Engineering Professional Practice

# %%
import pandas as pd
import io
import csv

output = """40. Circles and Arrows,Software Engineering Process
8 Pragmatic Projects,Software Engineering Management
41. Pragmatic Teams,Software Engineering Management
42. Ubiquitous Automation,Software Engineering Process
43. Ruthless Testing,Software Testing
44. It's All Writing,Software Engineering Professional Practice
45. Great Expectations,Software Engineering Management
46. Pride and Prejudice,Software Engineering Professional Practice"""

csv_reader = csv.reader(io.StringIO(output))
data = list(csv_reader)
df = pd.DataFrame(data, columns=["Titles_and_Sections", "SWEBOK_categories"]).iloc[1:]

xlsx_filename = "label_data.xlsx"

with pd.ExcelWriter(xlsx_filename, engine='xlsxwriter') as writer:
    df.to_excel(writer, index=False, sheet_name='Sheet1')

    workbook  = writer.book
    worksheet = writer.sheets['Sheet1']

    for i, col in enumerate(df.columns):
        max_len = max(df[col].astype(str).apply(len).max(), len(col))
        worksheet.set_column(i, i, max_len + 2)

print(f"Excel file '{xlsx_filename}' created successfully.")
# Out:
# Excel file 'label_data.xlsx' created successfully.
